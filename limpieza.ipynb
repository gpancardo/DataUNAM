# %% [markdown]
# # Limpieza 🧹

# %% [markdown]
# ## Importar dataset como dataframe de pandas.

# %%
import pandas as pd
df=pd.read_csv("unam.csv")
print(df.head())
# Out:
#    Institution ID                              Institution  Campus ID  \
# 0             604  Universidad Nacional Autónoma De México   60400001
# 1             604  Universidad Nacional Autónoma De México   60400001
# 2             604  Universidad Nacional Autónoma De México   60400001
# 3             604  Universidad Nacional Autónoma De México   60400001
# 4             604  Universidad Nacional Autónoma De México   60400001
#
#                                               Campus  Sex ID     Sex  Area ID  \
# 0  Escuela Nacional De Lenguas, Lingüística Y Tra...       1  Hombre        2
# 1  Escuela Nacional De Lenguas, Lingüística Y Tra...       1  Hombre        2
# 2  Escuela Nacional De Lenguas, Lingüística Y Tra...       1  Hombre        2
# 3  Escuela Nacional De Lenguas, Lingüística Y Tra...       1  Hombre        2
# 4  Escuela Nacional De Lenguas, Lingüística Y Tra...       1  Hombre        2
#
# ...

# %% [markdown]
# ### Notas
# Hay columnas que no son útiles para nuestro dashboard y el atributo __'Career'__ tiene elementos con nombres muy largos que no se verían claramente en el dashboard.

# %% [markdown]
# ## Reducir columnas

# %%
columnasNo=["Institution", "Institution ID", "Campus ID", "Sex ID", "Career ID","Academic Degree ID"]
df=df.drop(columnasNo, axis=1)

# %% [markdown]
# ## Siglas para ubicaciones
# Los nombres del atributo __'Campus'__ son muy largos y podrían ser difíciles de leer en el dashboard.

# %%
#Nombres de todas las ubicaciones
ubicacionesOriginales = df["Campus"].unique()

# %%
#Reemplazos
df["Campus"]=df["Campus"].replace("Instituto De Investigaciones Estéticas", "IIEst")
df["Campus"]=df["Campus"].replace("Universidad Nacional Autónoma De México - Ciudad Universitaria","CU")
df["Campus"]=df["Campus"].replace("Escuela Nacional De Lenguas, Lingüística Y Traducción", "ENALLT")
df["Campus"]=df["Campus"].replace("Universidad Nacional Autónoma De México - Escuela Nacional De Música", "ENM")
df["Campus"]=df["Campus"].replace("Instituto De Investigaciones En Matemáticas Aplicadas Y En Sistemas", "IIMAS")
df["Campus"]=df["Campus"].replace("Universidad Nacional Autónoma De México - Facultad De Estudios Superiores Zaragoza", "FESZ")
df["Campus"]=df["Campus"].replace("Universidad Nacional Autónoma De México - Escuela Nacional De Enfermería Y Obstetricia", "ENEO")
df["Campus"]=df["Campus"].replace("Universidad Nacional Autónoma De México - Escuela Nacional De Artes Plásticas", "ENAP")
df["Campus"]=df["Campus"].replace("Escuela Nacional De Estudios Superiores, Unidad León", "ENES León")
df["Campus"]=df["Campus"].replace("Universidad Nacional Autónoma De México - Facultad De Estudios Superiores Cuautitlán", "FESC")
df["Campus"]=df["Campus"].replace("Universidad Nacional Autónoma De México - Facultad De Estudios Superiores Acatlán", "FESAc")
df["Campus"]=df["Campus"].replace("Universidad Nacional Autónoma De México - Facultad De Estudios Superiores Aragón", "FESAr")
df["Campus"]=df["Campus"].replace("Universidad Nacional Autónoma De México - Facultad De Estudios Superiores Iztacala", "FESI")
df["Campus"]=df["Campus"].replace("Centro De Ciencias Genómicas De La Universidad Nacional Autónoma De México", "CCG")
df["Campus"]=df["Campus"].replace("Universidad Nacional Autónoma De México - Centro De Ciencias Genómicas", "CCG")
df["Campus"]=df["Campus"].replace("Centro De Ciencias Matemáticas", "CCM")
df["Campus"]=df["Campus"].replace("Centro De Física Aplicada Y Tecnología Avanzada", "CFATA")
df["Campus"]=df["Campus"].replace("Centro De Geociencias", "CG")
df["Campus"]=df["Campus"].replace("Centro De Investigaciones En Geografía Ambiental", "CIGA")
df["Campus"]=df["Campus"].replace("Centro De Investigaciones Multidisciplinarias Sobre Chiapas Y La Frontera Sur", "CIMCFS")
df["Campus"]=df["Campus"].replace("Centro De Nanociencias Y Nanotecnología", "CNN")
df["Campus"]=df["Campus"].replace("Centro Peninsular En Humanidades Y Ciencias Sociales", "CPHCS")
df["Campus"]=df["Campus"].replace("Escuela Nacional De Ciencias De La Tierra", "ENACT")
df["Campus"]=df["Campus"].replace("Escuela Nacional De Estudios Superiores Unidad Mérida", "")
df["Campus"]=df["Campus"].replace("Escuela Nacional De Estudios Superiores Unidad Morelia", "")
df["Campus"]=df["Campus"].replace("Escuela Nacional De Estudios Superiores, Unidad Juriquilla", "")
df["Campus"]=df["Campus"].replace("Instituto De Biotecnología", "IB")
df["Campus"]=df["Campus"].replace("Instituto De Energías Renovables", "IER")
df["Campus"]=df["Campus"].replace("Instituto De Investigaciones En Ecosistemas Y Sustentabilidad", "IIES")
df["Campus"]=df["Campus"].replace("Instituto De Neurobiología", "IN")
df["Campus"]=df["Campus"].replace("Instituto De Radioastronomía Y Astrofísica", "IRA")
df["Campus"]=df["Campus"].replace("Centro De Investigaciones Interdisciplinarias En Ciencias Y Humanidades", "CIICH")
df["Campus"]=df["Campus"].replace("Centro De Investigaciones Sobre América Latina Y El Caribe", "CIALC")
df["Campus"]=df["Campus"].replace("Instituto De Astronomía","IA")
df["Campus"]=df["Campus"].replace("Instituto De Ciencias Aplicadas Y Tecnología", "ICAT")
df["Campus"]=df["Campus"].replace("Instituto De Ciencias De La Atmósfera Y Cambio Climático", "ICACC")
df["Campus"]=df["Campus"].replace("Instituto De Ciencias Del Mar Y Limnología", "ICML")
df["Campus"]=df["Campus"].replace("Instituto De Biología", "IB")
df["Campus"]=df["Campus"].replace("Centro Regional De Investigaciones Multidisciplinarias", "CRIM")
df["Campus"]=df["Campus"].replace("Instituto De Ciencias Físicas", "ICF")
df["Campus"]=df["Campus"].replace("Instituto De Ciencias Nucleares", "ICN")
df["Campus"]=df["Campus"].replace("Instituto De Ecología", "IE")
df["Campus"]=df["Campus"].replace("Instituto De Física", "IF")
df["Campus"]=df["Campus"].replace("Instituto De Fisiología Celular", "IFC")
df["Campus"]=df["Campus"].replace("Instituto De Geofísica", "IG")
df["Campus"]=df["Campus"].replace("Instituto De Geografía", "IGeo")
df["Campus"]=df["Campus"].replace("Instituto De Geología", "IGeología")
df["Campus"]=df["Campus"].replace("Instituto De Ingeniería", "II")
df["Campus"]=df["Campus"].replace("Instituto De Investigaciones Antropológicas", "IIA")
df["Campus"]=df["Campus"].replace("Instituto De Investigaciones Bibliotecológicas Y De La Información", "IIBI")
df["Campus"]=df["Campus"].replace("Instituto De Investigaciones Biomédicas", "IIBiomed")
df["Campus"]=df["Campus"].replace("Instituto De Investigaciones Económicas", "IIE")
df["Campus"]=df["Campus"].replace("Instituto De Investigaciones En Materiales", "IIM")
df["Campus"]=df["Campus"].replace("Instituto De Investigaciones Filológicas", "IIF")
df["Campus"]=df["Campus"].replace("Instituto De Investigaciones Jurídicas", "IIJ")
df["Campus"]=df["Campus"].replace("Instituto De Investigaciones Sobre La Universidad Y La Educación", "IIUE")
df["Campus"]=df["Campus"].replace("Instituto De Investigaciones Sociales", "IIS")
df["Campus"]=df["Campus"].replace("Instituto De Matemáticas", "IM")
df["Campus"]=df["Campus"].replace("Instituto De Química", "IQ")
df["Campus"]=df["Campus"].replace("Escuela Nacional De Artes Cinematográficas", "ENAC")


print(df["Campus"])
# Out:
# 0       ENALLT
# 1       ENALLT
# 2       ENALLT
# 3       ENALLT
# 4       ENALLT
#          ...
# 4564      CRIM
# 4565       CCG
# 4566       CCG
# 4567       CCG
# 4568       CCG
# Name: Campus, Length: 4569, dtype: object

# %% [markdown]
# ## Reducir títulos
# Recortar elementos redundantes de los títulos (__'Career'__) para simplificar lectura. Esta información también está disponible en el atributo __'Academic Degree'__.

# %%
df["Career"].unique()
# Out:
# array(['Licenciatura en lingüística aplicada',
#        'Maestría en lingüística hispánica', 'Licenciatura en traducción',
#        'Doctorado en lingüística',
#        'Especialidad en enseñanza de español como lengua extranjera',
#        'Maestría en lingüística aplicada',
#        'Maestría en docencia para la educación media superior: química',
#        'Maestría en docencia para la educación media superior: ciencias sociales',
#        'Maestría en docencia para la educación media superior: matemáticas',
#        'Maestría en docencia para la educación media superior: biología',
#        'Maestría en docencia para la educación media superior: geografía',
#        'Maestría en docencia para la educación media superior: español',
#        'Maestría en pedagogía',
#        'Maestría en docencia para la educación media superior: letras',
#        'Maestría en docencia para la educación media superior: física',
# ...

# %% [markdown]
# Regex para eliminar las substrings redundantes

# %%
#Licenciatura
df['Career'] = df['Career'].str.replace(r'^Licenciatura\s+en\s+', '', regex=True)
#Especialidad
df['Career'] = df['Career'].str.replace(r'^Especialidad\s+en\s+', '', regex=True)
#Especialización
df['Career'] = df['Career'].str.replace(r'^Especialización\s+en\s+', '', regex=True)
#Maestría
df['Career'] = df['Career'].str.replace(r'^Maestría\s+en\s+', '', regex=True)
#Doctorado
df['Career'] = df['Career'].str.replace(r'^Doctorado\s+en\s+', '', regex=True)
#Ingeniería
df['Career'] = df['Career'].str.replace(r'^Ingeniería\s+en\s+', '', regex=True)
#PUE
df['Career'] = df['Career'].str.replace(r'^Programa\súnico\sde\sespecialidades\s+en\s+', '', regex=True)

df['Career'] = df['Career'].str.replace(r'la\s+enseñanza', 'Enseñanza', regex=True)
df['Career'] = df['Career'].str.replace(r'docencia\s+para\s+la\s+educación\s+media\s+superior:', 'DEMS', regex=True)

df['Career'].unique()
# Out:
# array(['lingüística aplicada', 'lingüística hispánica', 'traducción',
#        'lingüística', 'enseñanza de español como lengua extranjera',
#        'DEMS química', 'DEMS ciencias sociales', 'DEMS matemáticas',
#        'DEMS biología', 'DEMS geografía', 'DEMS español', 'pedagogía',
#        'DEMS letras', 'DEMS física', 'DEMS filosofía', 'DEMS historia',
#        'DEMS inglés', 'docencia para la educación media superior',
#        'DEMS ciencias de la salud', 'DEMS francés', 'DEMS psicología',
#        'docencia en artes y diseño', 'historia del arte',
#        'estudios mesoamericanos',
#        'lengua y literatura moderna (francesas)',
#        'arquitectura de interiores',
#        'lengua y literaturas modernas (letras portuguesas)', 'filosofía',
#        'historia', 'filosofía de la ciencia', 'letras',
#        'diseño industrial', 'lengua y literaturas modernas (italianas)',
#        'cine documental', 'estudios latinoamericanos', 'música',
# ...

# %%
df['Career'] = df['Career'].apply(lambda x: x.capitalize()) 
df["Career"].unique()
# Out:
# array(['Lingüística aplicada', 'Lingüística hispánica', 'Traducción',
#        'Lingüística', 'Enseñanza de español como lengua extranjera',
#        'Dems química', 'Dems ciencias sociales', 'Dems matemáticas',
#        'Dems biología', 'Dems geografía', 'Dems español', 'Pedagogía',
#        'Dems letras', 'Dems física', 'Dems filosofía', 'Dems historia',
#        'Dems inglés', 'Docencia para la educación media superior',
#        'Dems ciencias de la salud', 'Dems francés', 'Dems psicología',
#        'Docencia en artes y diseño', 'Historia del arte',
#        'Estudios mesoamericanos',
#        'Lengua y literatura moderna (francesas)',
#        'Arquitectura de interiores',
#        'Lengua y literaturas modernas (letras portuguesas)', 'Filosofía',
#        'Historia', 'Filosofía de la ciencia', 'Letras',
#        'Diseño industrial', 'Lengua y literaturas modernas (italianas)',
#        'Cine documental', 'Estudios latinoamericanos', 'Música',
# ...

# %% [markdown]
# ## Guardar nuevo CSV

# %%
df.to_csv('unamLimpio.csv', columns=df.columns[0:], index=False)
